# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_RandomForestclassifier.sav",'rb'))
result=loaded_model.predict([[78,89000,0]])
result
# Out:
# C:\Users\PAVAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1])
